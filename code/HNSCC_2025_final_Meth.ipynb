# %% [markdown]
# ## Import Packages

# %%
# import packages
# Importing all necessary packages

import numpy as np
import pandas as pd
#from sklearn.decomposition import PCA
import collections
from sklearn.model_selection import train_test_split

# importing os module
import os
import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import mutual_info_classif, SelectKBest

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
import xgboost as xgb
from sklearn import svm
from sklearn.svm import SVC

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from sklearn.feature_selection import SelectFromModel

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
#import shap
import random
import scipy
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Boxplot

# %%
def measure_boxplot(df_measure_imp, df_measure_random, filepath, title):
    df_imp_long = df_measure_imp.melt(var_name="Model", value_name="Accuracy")
    df_imp_long["Type"] = "Important"
    df_rand_long = df_measure_random.melt(var_name="Model", value_name="Accuracy")
    df_rand_long["Type"] = "Random"
    df_all = pd.concat([df_imp_long, df_rand_long], ignore_index= True)

    # calculating p-val
    p_cv_logr = float(scipy.stats.wilcoxon(df_measure_imp["LogR"], df_measure_random["LogR"],alternative = "greater")[1])
    #print(p_cv_logr)
    p_cv_RF = float(scipy.stats.wilcoxon(df_measure_imp["RF"], df_measure_random["RF"], alternative = "greater")[1])
    #print(p_cv_RF)
    p_cv_MLP = float(scipy.stats.wilcoxon(df_measure_imp["MLP"], df_measure_random["MLP"], alternative = "greater")[1])
    #print(p_cv_MLP)
    p_cv_SVC = float(scipy.stats.wilcoxon(df_measure_imp["SVC"], df_measure_random["SVC"], alternative = "greater")[1])
    #print(p_cv_SVC)
    pvals = {"LogR":p_cv_logr, "RF":p_cv_RF, "MLP":p_cv_MLP, "SVC": p_cv_SVC}
    plt.figure(figsize=(10,7))
    ax = sns.boxplot(x="Model", y="Accuracy", hue="Type", data=df_all, palette="Set2")

    # Add p-values above boxes
    for i, model in enumerate(df_all["Model"].unique()):
        y = df_all[df_all["Model"]==model]["Accuracy"].max() + 0.002  # position above box
        p = pvals[model]
        ax.text(i, y, f"p = {p:.3e}", ha="center", va="bottom", fontsize=10, color="black")

    plt.title(title)
    plt.ylabel("Accuracy")
    plt.legend(title="Gene Set")    
    plt.savefig(filepath, dpi= 400)

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Split Function: Splits the data into train and test
#
# x: input
#
# y:output

# %%
def split(x, y, random_state): # x and y are raw
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=random_state)
    # data without imputation and target values
    return x_train, x_test, y_train, y_test # _0 retaines sample type information _1 are without sample type info

# %% [markdown]
# #### 2. Random Selection: randomly selects a set of n features

# %%
def random_selection(num, all_features, random_state):
    # num is the feature set size to be selected
    # all_features = total pool of features
    # random selection of columns
    random.seed(random_state)
    features = []
    features = random.sample(all_features, num)
    return features

# %% [markdown]
# 3. Min-Max Scaling

# %%
def minmax_scaling(x_train, x_test):

    scaler = MinMaxScaler()
    scaler.fit(x_train)
    x_train = pd.DataFrame(scaler.transform(x_train), columns=x_train.columns, index=x_train.index)
    x_test = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns, index=x_test.index)
    return x_train, x_test

# %%
def impute(x_train, x_test):
    imputer = KNNImputer(n_neighbors=5)
    imputer.fit(x_train)
    x_train = pd.DataFrame(imputer.transform(x_train), columns=x_train.columns, index=x_train.index)
    x_test = pd.DataFrame(imputer.transform(x_test), columns=x_test.columns, index=x_test.index)
    return x_train, x_test

# %% [markdown]
# Evaluation

# %%
def eval(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, pos_label = "Tumor")
    precision = precision_score(y_true,y_pred, pos_label = "Tumor")
    recall = recall_score(y_true, y_pred, pos_label = "Tumor")
    auc = roc_auc_score(y_true, y_pred)
    return acc, f1, precision, recall

# %% [markdown]
# #### Classification task

# %%
def classification_task(x_train, x_test, y_train, y_test, models, model_names, random_state):
        
        # accuracy dictionary
        accuracy_cv = {} # iteration over seeds
        accuracy_pred = {} # iteration over seeds
      
        i = 0
        for est in models: 
                model_name = model_names[i]
                i = i + 1
                est = est.fit(x_train, y_train)

                #  Stratified Cross validation
                cv = StratifiedKFold(n_splits=5, shuffle=True, random_state = random_state)
                y_pred_CV = cross_val_predict(est, x_train, y_train, cv=cv)               
                report_CV = classification_report(y_train, y_pred_CV, target_names=["Normal", "Tumor"], output_dict=True)
                acc = report_CV["accuracy"]
                accuracy_cv[model_name] = acc


                # prediction
                y_pred = est.predict(x_test)

                report = classification_report(y_test, y_pred, target_names=["Normal", "Tumor"], output_dict=True)
                acc = report["accuracy"]
                accuracy_pred[model_name] = acc
                # returns directory for models
        return accuracy_cv, accuracy_pred

# %% [markdown]
# ### Feature Selection:Mutual Information

# %%
def get_miscores(X, y, random_state):
    mi_scores = mutual_info_classif(X, y, random_state=random_state)
    return mi_scores
def get_migenes(x, y, k, random_state):
    mi_df  = pd.DataFrame(columns=["gene", "MI_score"])
    mi_df["gene"] = x.columns
    random.seed(random_state)
    seeds = random.sample(range(0, 1000), 3)
    for seed in seeds: # you can increase the list of seeds
        mi_scores= get_miscores(x, y, random_state=seed)
        mi_df[seed] = mi_scores
        # Mi_score column is mean of all seeds
    mi_df["MI_score"] = mi_df.iloc[:, 1:4].mean(axis=1)

    mi_df = mi_df.sort_values(by="MI_score", ascending=False)
        
    top_1000_df = mi_df.head(k)
    top_genes_mi = mi_df["gene"].tolist()[:k]
    
    # returns the list and dataframe
    return top_genes_mi, top_1000_df

# %% [markdown]
# ### Feature Selection: RF-SelectFromModel

# %%
def RFSFM(x_train, x_test,y_train, y_test, random_state):
    # Using RandomForestClassifier as the estimator
    rf = RandomForestClassifier(n_estimators=500, random_state=random_state)
    # Using SelectFromModel to select top 100 features
    selector = SelectFromModel(rf, max_features=100, threshold="median")
    selector.fit(x_train, y_train)
    selected_features = x_train.columns[selector.get_support()]
    x_train_rf = x_train[selected_features]
    x_test_rf = x_test[selected_features]
    return x_train_rf, x_test_rf, selected_features

# %% [markdown]
# ### Feature Selection: SVMRFE

# %%
def svm_rfe(x_train, y_train, features, random_state): # returns dataframe of features 
    # min = min numbers of features to be selected
    
    # cross validation to be used in RFECV
    cv = StratifiedKFold(n_splits = 5, shuffle = True, random_state = random_state)
    
    # using SVC estimator to check Features importance using RFE 
    svc = svm.SVC(kernel = "linear", random_state=random_state)
    # RFECV optimizes the minimum set of features needed for cassification task
    rfecv_SVM = RFECV(svc, min_features_to_select = 20, cv=cv, scoring='f1_weighted',  n_jobs=-1)
    fit_rfecv_SVM = rfecv_SVM.fit(x_train, y_train)
    
    RFECV_SVM_Top_Feat_df = pd.DataFrame({'Features': features, 'Selected': fit_rfecv_SVM.support_,
                                  'Rank': fit_rfecv_SVM.ranking_})
    RFECV_SVM_Top_Feat_df = RFECV_SVM_Top_Feat_df.sort_values(by = 'Rank')
 
    return RFECV_SVM_Top_Feat_df

# %% [markdown]
# #### Ploting ROC

# %%
# function to plot ROC curve
def roc(model_list, x_test, y_test):
    disp = RocCurveDisplay.from_estimator(model_list[0], x_test, y_test, pos_label='Tumor', name ="LogR", lw = 5)
    RocCurveDisplay.from_estimator(model_list[1], x_test, y_test, pos_label='Tumor', ax=disp.ax_, name ="RF", lw = 5);
    RocCurveDisplay.from_estimator(model_list[2], x_test, y_test, pos_label='Tumor', ax=disp.ax_, name ="MLP", lw = 5);
    RocCurveDisplay.from_estimator(model_list[3], x_test, y_test, pos_label='Tumor', ax=disp.ax_, name ="SVC", lw = 5); 
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.rc("font", size = 20)
    plt.legend(fontsize = "16", frameon = False)
    plt.title("100 genes (ANOVA)")
    plt.savefig("00-1_ROC_Top_100_Cancer.png", dpi=400, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## MAIN

# %% [markdown]
# ### Getting the data ready for the main process

# %%
data_df = pd.read_csv("data/processed/Methylation_processed.csv", index_col=0)
print(data_df.shape)
x = data_df.drop(columns=["Sample_Type"])
y = data_df["Sample_Type"]
# Out:
# (144, 3728)

# %%
data_df.head(5)
# Out:
#               AADAT      AARD      AATK     ABCA1    ABCA13     ABCA3  \
# C3L-00977  0.038071  0.056605  0.687841  0.213348  0.870581  0.183555
# C3L-00994  0.014974  0.060466  0.673046  0.251102  0.941043  0.155491
# C3L-00995  0.013376  0.042229  0.696704  0.192152  0.775686  0.147408
# C3L-00997  0.018231  0.042851  0.706655  0.242499  0.888122  0.169314
# C3L-00999  0.027507  0.099660  0.695575  0.249732  0.917108  0.145448
#
#               ABCB4     ABCB6     ABCC3     ABCC8  ...      ZPBP     ZPBP2  \
# C3L-00977  0.017020  0.035709  0.027295  0.078749  ...  0.296491  0.064447
# C3L-00994  0.021802  0.022689  0.015880  0.027910  ...  0.372693  0.125821
# C3L-00995  0.009670  0.023249  0.015960  0.084621  ...  0.047035  0.103317
# C3L-00997  0.013828  0.040922  0.013789  0.058464  ...  0.214118  0.193016
# C3L-00999  0.011121  0.030233  0.015351  0.082682  ...  0.270763  0.137667
#
#              ZSCAN1   ZSCAN12   ZSCAN18   ZSCAN20    ZSWIM2    ZYG11A  \
# C3L-00977  0.127544  0.029267  0.117757  0.022517  0.131707  0.016943
# C3L-00994  0.077159  0.018611  0.097113  0.021926  0.140021  0.015253
# C3L-00995  0.141067  0.074867  0.078405  0.025330  0.141877  0.013534
# C3L-00997  0.160894  0.019809  0.131519  0.024987  0.089601  0.014490
# C3L-00999  0.150762  0.016050  0.074638  0.025352  0.116304  0.012766
#
#              ZYG11B  Sample_Type
# C3L-00977  0.018770       Normal
# C3L-00994  0.075496       Normal
# C3L-00995  0.074321       Normal
# C3L-00997  0.017932       Normal
# C3L-00999  0.050437       Normal
#
# [5 rows x 3728 columns]

# %%
# check if missing values are present
data_df.isnull().sum().sum()
# Out:
# np.int64(98)

# %% [markdown]
# ## MAIN LOOP -- Loops for 100 random states

# %%
# iteration of random seeds

# dictionaries to store results
# dict to store selected genes from MI and SVM-RFE
# dtaaframe to store results
dict_mi = {}
dict_svmrfe = {}
dict_rfsfm = {}
dict_acc_cv = {"LogR":[], "RF":[], "MLP":[], "SVC":[]}
dict_acc_pred = {"LogR":[], "RF":[], "MLP":[], "SVC":[]}
dict_acc_cv_random = {"LogR":[], "RF":[], "MLP":[], "SVC":[]}
dict_acc_pred_random = {"LogR":[], "RF":[], "MLP":[], "SVC":[]}
for i in range(100):
    random_state = i
    print("------------------------------------------------------------------")
    print("Iteration: ", i+1)
    print ("Random state: ", random_state)
    # train-test split
    x_train, x_test, y_train, y_test = split(x,y,random_state)

    # imputation of missing values
    x_train, x_test = impute(x_train, x_test)

    # Min-Max Scaling
    x_train, x_test = minmax_scaling(x_train, x_test)

    # Mutual Information based feature selection -- gives top 1000 genes
    top_genes_mi, top_1000_df = get_migenes(x_train, y_train, 1000, random_state)
    dict_mi[random_state] = top_genes_mi

    print("Top 1000 genes selected using MI")
   
    # updated x_train and x_test
    x_train_mi = x_train[top_genes_mi]
    x_test_mi = x_test[top_genes_mi]
    
    # Random forest based feature selection -- gives top 100 genes using SlectFromModel
    x_train_rfsfm, x_test_rfsfm, features_rfsfm = RFSFM(x_train_mi, x_test_mi, y_train, y_test, random_state)
    dict_rfsfm[random_state] = features_rfsfm.tolist()
    print("Top genes selected using RF-SelectFromModel: ", len(features_rfsfm))
    

    # SVM-RFE based feature selection -- gives top genes selected by SVM-RFE (not a fixed range)
    svm_rfe_df = svm_rfe(x_train_rfsfm, y_train, features_rfsfm, random_state) # returns dataframe of features (all features with selected True/False)

# selected features from SVM-RFE
    features_svmrfe = svm_rfe_df [svm_rfe_df['Selected'] == True]['Features'].tolist()
    dict_svmrfe[random_state] = features_svmrfe

    print("Top genes selected using SVM-RFE: ", len(features_svmrfe))

    # updated x_train and x_test
    x_train_svmrfe = x_train_rfsfm[features_svmrfe]
    x_test_svmrfe = x_test_rfsfm[features_svmrfe]

    # running 4 classifiers for evaltuion
    logr = LogisticRegression(random_state=random_state, max_iter=800, solver='liblinear')
    rf = RandomForestClassifier(random_state=random_state, n_estimators=500)
    mlp = MLPClassifier(random_state=random_state, max_iter=800, activation="relu", solver='lbfgs', alpha=1e-5)
    svc = SVC(random_state=random_state, kernel = "linear", C = 0.1)


    models = [logr, rf, mlp, svc]
    model_names = ["LogR", "RF", "MLP", "SVC"]

    # returns dictionary for models
    acc_cv, acc_pred = classification_task(x_train_svmrfe, x_test_svmrfe, y_train, y_test, models, model_names, random_state)    
    for key in acc_cv.keys():
        dict_acc_cv[key].append(acc_cv[key])
    for key in acc_pred.keys():
        dict_acc_pred[key].append(acc_pred[key])
        print(f"Accuracy for mode {key}: {acc_pred[key]}")

    print("Classification task using SVM-RFE selected genes done")

# random features for comparison

    num_features = len(features_svmrfe)
    all_features = x.columns.tolist()
    random_features = random_selection(num_features, all_features, random_state)
    x_train_random = x_train[random_features]
    x_test_random = x_test[random_features]

    # classification task
    acc_cv, acc_pred = classification_task(x_train_random, x_test_random, y_train, y_test, models, model_names, random_state)    
    for key in acc_cv.keys():
        dict_acc_cv_random[key].append(acc_cv[key])
    for key in acc_pred.keys():
        dict_acc_pred_random[key].append(acc_pred[key])
        print(f"Accuracy for mode {key}: {acc_pred[key]}")

    print("Classification task using Randomly selected genes done")
# Out:
# ------------------------------------------------------------------
# Iteration:  1
# Random state:  0
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  2
# Random state:  1
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  3
# Random state:  2
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  4
# Random state:  3
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  23
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.6896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  5
# Random state:  4
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.7931034482758621
# Accuracy for mode RF: 0.7931034482758621
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.5172413793103449
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  6
# Random state:  5
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  7
# Random state:  6
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  30
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  8
# Random state:  7
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  9
# Random state:  8
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  21
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  10
# Random state:  9
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  23
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  11
# Random state:  10
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  12
# Random state:  11
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  24
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  13
# Random state:  12
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  30
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  14
# Random state:  13
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  15
# Random state:  14
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  16
# Random state:  15
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  23
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  17
# Random state:  16
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.7241379310344828
# Accuracy for mode RF: 0.7931034482758621
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.6896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  18
# Random state:  17
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  27
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  19
# Random state:  18
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  28
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.7931034482758621
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  20
# Random state:  19
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  31
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  21
# Random state:  20
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  22
# Random state:  21
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  48
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  23
# Random state:  22
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  29
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  24
# Random state:  23
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  60
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  25
# Random state:  24
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  26
# Random state:  25
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.7586206896551724
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  27
# Random state:  26
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  39
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  28
# Random state:  27
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  29
# Random state:  28
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  35
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  30
# Random state:  29
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  37
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  31
# Random state:  30
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  32
# Random state:  31
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.7931034482758621
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  33
# Random state:  32
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.6896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  34
# Random state:  33
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  35
# Random state:  34
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  36
# Random state:  35
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  37
# Random state:  36
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.7586206896551724
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  38
# Random state:  37
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  39
# Random state:  38
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  40
# Random state:  39
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  21
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  41
# Random state:  40
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.7931034482758621
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.7586206896551724
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  42
# Random state:  41
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  43
# Random state:  42
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  44
# Random state:  43
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  69
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  45
# Random state:  44
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  46
# Random state:  45
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  47
# Random state:  46
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.7586206896551724
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  48
# Random state:  47
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  21
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  49
# Random state:  48
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  34
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  50
# Random state:  49
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  52
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  51
# Random state:  50
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  52
# Random state:  51
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  24
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  53
# Random state:  52
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  54
# Random state:  53
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  64
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  55
# Random state:  54
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  56
# Random state:  55
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  21
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  57
# Random state:  56
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  58
# Random state:  57
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  59
# Random state:  58
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  60
# Random state:  59
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  33
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  61
# Random state:  60
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.5517241379310345
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  62
# Random state:  61
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  63
# Random state:  62
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  64
# Random state:  63
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  24
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  65
# Random state:  64
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  42
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  66
# Random state:  65
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  54
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  67
# Random state:  66
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.896551724137931
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  68
# Random state:  67
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  39
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  69
# Random state:  68
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  70
# Random state:  69
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  49
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  71
# Random state:  70
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  72
# Random state:  71
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  73
# Random state:  72
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  44
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  74
# Random state:  73
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  23
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7586206896551724
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  75
# Random state:  74
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.7241379310344828
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  76
# Random state:  75
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  77
# Random state:  76
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  35
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  78
# Random state:  77
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  79
# Random state:  78
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  41
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  80
# Random state:  79
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  30
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8275862068965517
# Accuracy for mode SVC: 0.8275862068965517
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  81
# Random state:  80
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  24
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  82
# Random state:  81
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  83
# Random state:  82
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  40
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  84
# Random state:  83
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  85
# Random state:  84
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  25
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8275862068965517
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.7586206896551724
# Accuracy for mode SVC: 0.6551724137931034
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  86
# Random state:  85
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  23
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  87
# Random state:  86
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.7586206896551724
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.7586206896551724
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  88
# Random state:  87
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.6896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  89
# Random state:  88
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  30
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  90
# Random state:  89
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.6206896551724138
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  91
# Random state:  90
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  39
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  92
# Random state:  91
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  93
# Random state:  92
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.8620689655172413
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.7931034482758621
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  94
# Random state:  93
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  28
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 0.8620689655172413
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  95
# Random state:  94
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  96
# Random state:  95
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9310344827586207
# Accuracy for mode RF: 0.9310344827586207
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.9310344827586207
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  97
# Random state:  96
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  21
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  98
# Random state:  97
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.8620689655172413
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.896551724137931
# Accuracy for mode SVC: 0.8620689655172413
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  99
# Random state:  98
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  22
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 1.0
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 1.0
# Accuracy for mode RF: 1.0
# Accuracy for mode MLP: 1.0
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done
# ------------------------------------------------------------------
# Iteration:  100
# Random state:  99
# Top 1000 genes selected using MI
# Top genes selected using RF-SelectFromModel:  100
# Top genes selected using SVM-RFE:  20
# Accuracy for mode LogR: 0.9655172413793104
# Accuracy for mode RF: 0.9655172413793104
# Accuracy for mode MLP: 0.9655172413793104
# Accuracy for mode SVC: 0.9655172413793104
# Classification task using SVM-RFE selected genes done
# Accuracy for mode LogR: 0.896551724137931
# Accuracy for mode RF: 0.896551724137931
# Accuracy for mode MLP: 0.9310344827586207
# Accuracy for mode SVC: 0.896551724137931
# Classification task using Randomly selected genes done

# %%
# saving results

#-----genes--------------
# MI selected genes --fixed number 1000
df_mi_df = pd.DataFrame()
for key in dict_mi.keys():
    df_mi_df[key] = dict_mi[key]
df_mi_df.to_csv("results/SO/M/00-1_Top_1000_genes_MI_M.csv")

#RFSFM Selected genes -- number can vary 
df_rfsfm = pd.DataFrame()
for key in dict_rfsfm.keys():
    df_rfsfm[key] = [dict_rfsfm[key]]
df_rfsfm.to_csv("results/SO/M/00-1_Top_genes_RFSFM_M.csv")

# SVMRFE selected gene -- number can vary
df_svmrfe = pd.DataFrame()
for key in dict_svmrfe.keys():
    df_svmrfe[key] = [dict_svmrfe[key]]
df_svmrfe.to_csv("results/SO/M/00-1_Top_genes_SVMRFE_M.csv") 


#-------performance measures -------------

# Cross validation SVMRFE
df_acc_cv = pd.DataFrame(dict_acc_cv)
df_acc_cv.to_csv("results/SO/M/00-1_Accuracy_CV_SVMRFE_M.csv")

# Test SVMRFE
df_acc_pred = pd.DataFrame(dict_acc_pred)
df_acc_pred.to_csv("results/SO/M/00-1_Accuracy_Pred_SVMRFE_M.csv")

# Cross Validation Random
df_acc_cv_random = pd.DataFrame(dict_acc_cv_random)
df_acc_cv_random.to_csv("results/SO/M/00-1_Accuracy_CV_Random_M.csv")

# Test Random
df_acc_pred_random = pd.DataFrame(dict_acc_pred_random)
df_acc_pred_random.to_csv("results/SO/M/00-1_Accuracy_Pred_Random_M.csv")

# %% [markdown]
# ## FINAL results over selected gene set

# %% [markdown]
# ### SVMRFE

# %%
# finding the most reoccuring top 10 genes from SVMRFE
num = []
dict_gene_freq = {}

for key in dict_svmrfe.keys():
    num.append(len(dict_svmrfe[key]))
    for gene in dict_svmrfe[key]:
        if gene in dict_gene_freq:
            dict_gene_freq[gene] += 1
        else:
            dict_gene_freq[gene] = 1

# %%
len(dict_svmrfe)
# Out:
# 100

# %%
len(num)
# Out:
# 100

# %%
# histogram
plt.figure(figsize=(8,6))
plt.hist(num, bins = 100)
plt.title('Distribution of number of genes selected in SVMRFE step (Methylomics)')
plt.xlabel('Number of Genes', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
df_gene_freq = pd.DataFrame.from_dict(dict_gene_freq, orient="index")

# %%
df_gene_freq_svmrfe = df_gene_freq.sort_values(by = 0, ascending = False)

# %%
df_gene_freq_svmrfe.to_csv("results/SO/M/00-1_SVMRFE_GENEFreq.csv")

# %%
df_gene_freq_svmrfe.head(20)
# Out:
#            0
# GRM6      99
# FOXR1     95
# GPR75     78
# VSX1      78
# NLRP4     72
# SMPD3     70
# CCDC181   67
# AATK      66
# VSTM2A    65
# COX8C     62
# SPIN2A    58
# NT5DC3    57
# GRIN2B    54
# ABCC9     52
# FOXD2     47
# RGN       46
# UBBP4     43
# TAC1      38
# ADAMTS18  38
# KBTBD12   38

# %% [markdown]
# ### RFSFM

# %%
# finding the most reoccuring top 10 genes from SVMRFE
num = []
dict_gene_freq = {}

for key in dict_rfsfm.keys():
    num.append(len(dict_rfsfm[key]))
    for gene in dict_rfsfm[key]:
        if gene in dict_gene_freq:
            dict_gene_freq[gene] += 1
        else:
            dict_gene_freq[gene] = 1
len(dict_rfsfm), len(num)
# Out:
# (100, 100)

# %%
# histogram
plt.figure(figsize=(8,6))
plt.hist(num, bins = 200)
plt.title('Distribution of number of genes selected in RFSFM step (Transcriptomics)')
plt.xlabel('Number of Genes', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
df_gene_freq = pd.DataFrame.from_dict(dict_gene_freq, orient = "index")
df_gene_freq_svmrfe = df_gene_freq.sort_values(by = 0, ascending = False)
df_gene_freq_svmrfe.to_csv("results/SO/M/00-1_RFSFM_GENEFreq_M.csv")
df_gene_freq_svmrfe.head(20)
# Out:
#             0
# HOXD12    100
# NKAPL     100
# RGS22     100
# NLRP4     100
# BOLL      100
# FAM135B   100
# BRDT      100
# GRM6      100
# ABCC9      99
# HOXD9      99
# ZNF578     99
# VSX1       99
# PCDH17     99
# ADAMTS20   99
# ZNF132     99
# HAS1       98
# CCDC181    98
# NMBR       97
# GPR75      97
# ZBED9      96

# %% [markdown]
# ### MI

# %%
# finding the most reoccuring top 10 genes from SVMRFE
num = []
dict_gene_freq = {}

for key in dict_mi.keys():
    num.append(len(dict_mi[key]))
    for gene in dict_mi[key]:
        if gene in dict_gene_freq:
            dict_gene_freq[gene] += 1
        else:
            dict_gene_freq[gene] = 1
len(dict_mi), len(num)
# Out:
# (100, 100)

# %%
df_gene_freq = pd.DataFrame.from_dict(dict_gene_freq, orient = "index")
df_gene_freq_svmrfe = df_gene_freq.sort_values(by = 0, ascending = False)
df_gene_freq_svmrfe.to_csv("results/SO/M/00-1_MI_GENEFreq_M.csv")
df_gene_freq_svmrfe.head(20)
# Out:
#            0
# VSX1     100
# HAS1     100
# HOXD12   100
# PCDH17   100
# PIK3R5   100
# ST8SIA5  100
# SOX11    100
# PAPOLB   100
# SYCP1    100
# CHAT     100
# FIGLA    100
# ZNF835   100
# SMPD3    100
# ABCC9    100
# PABPC5   100
# ATP13A3  100
# NMBR     100
# MEI1     100
# NPTX2    100
# ZIK1     100

# %% [markdown]
# ### Boxplot accuracy comparision

# %%
df_acc_cv = pd.read_csv("results/SO/M/00-1_Accuracy_CV_SVMRFE_M.csv", index_col = 0)
df_acc_cv_random = pd.read_csv("results/SO/M/00-1_Accuracy_CV_Random_M.csv", index_col = 0)
df_acc_pred = pd.read_csv("results/SO/M/00-1_Accuracy_Pred_SVMRFE_M.csv", index_col = 0)
df_acc_pred_random = pd.read_csv("results/SO/M/00-1_Accuracy_Pred_Random_M.csv", index_col =0 )

# %%
filepath = "results/SO/M/00-1_Fig_Acc_CV_M.jpeg"
title = "Model Accuracies Cross Validation: Important vs Random Geneset (Methylomics))"
measure_boxplot(df_acc_cv, df_acc_cv_random, filepath, title)
filepath = "results/SO/M/00-1_Fig_Acc_pred_M.jpeg"
title = "Model Accuracies Test-set: Important vs Random Geneset (Methylomics)"
measure_boxplot(df_acc_pred, df_acc_pred_random, filepath, title)
